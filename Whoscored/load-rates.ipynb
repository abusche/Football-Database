# %% [markdown]
# # I. Whoscored Links Current Month

# %%
from Whoscored.links_functions import get_link_current_month

urls = ["https://fr.whoscored.com/regions/206/tournaments/4/seasons/10317/stages/23401/fixtures/espagne-laliga-2024-2025",
        "https://fr.whoscored.com/regions/108/tournaments/5/seasons/10375/stages/23490/fixtures/italie-serie-a-2024-2025",
        "https://fr.whoscored.com/regions/81/tournaments/3/seasons/10365/stages/23471/fixtures/allemagne-bundesliga-2024-2025",
        "https://fr.whoscored.com/regions/74/tournaments/22/seasons/10329/stages/23414/fixtures/france-ligue-1-2024-2025",
        "https://fr.whoscored.com/regions/252/tournaments/2/seasons/10316/stages/23400/fixtures/angleterre-premier-league-2024-2025"]

links = get_link_current_month(urls[3])
links
# Out:
# ['https://fr.whoscored.com/matches/1825026/live/france-ligue-1-2024-2025-nice-reims',
#  'https://fr.whoscored.com/matches/1824941/live/france-ligue-1-2024-2025-strasbourg-paris-saint-germain',
#  'https://fr.whoscored.com/matches/1824940/live/france-ligue-1-2024-2025-toulouse-rennes',
#  'https://fr.whoscored.com/matches/1825028/live/france-ligue-1-2024-2025-saint-etienne-monaco',
#  'https://fr.whoscored.com/matches/1825029/live/france-ligue-1-2024-2025-nantes-angers',
#  'https://fr.whoscored.com/matches/1825027/live/france-ligue-1-2024-2025-brest-montpellier',
#  'https://fr.whoscored.com/matches/1824943/live/france-ligue-1-2024-2025-auxerre-le-havre',
#  'https://fr.whoscored.com/matches/1825024/live/france-ligue-1-2024-2025-lyon-lens',
#  'https://fr.whoscored.com/matches/1825025/live/france-ligue-1-2024-2025-lille-marseille']

# %% [markdown]
# # II. Whoscored Links

# %%
from links_functions import get_link_whoscored

get_link_whoscored(1820000, 1821000)
# Out:
# 100%|██████████| 1001/1001 [28:09<00:00,  1.69s/it]

# %%
from links_functions import update_link

update_link(10000, "asc")
# Out:
#  35%|███▍      | 3471/10000 [1:40:01<2:44:46,  1.51s/it]

# %%
from links_functions import show_links

show_links()
# Out:
# Données transformées :
# Intervalle des données : 1820000 1843468
# Links : 20074
# Not availables : 3386
# Errors : 0
# Nombre d'observation : 23460
#
# Données brutes :
# Intervalle des données : 1820000 1839999.0
# Links : 20074
# Not availables : 3386
# Errors : 0
# Nombre d'observation : 23460
#
# Links :
# <table id="itables_fc9b0e53_2c6d_4209_b216_8a29e8892b82" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>link</th>
#       <th>num_lien</th>
#       <th>league</th>
#       <th>annee</th>
#       <th>equipes</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
# ...

# %%
from links_functions import clean_links

clean_links()

# %% [markdown]
# # III. Rates

# %%
from rates_database import get_rates_database
import pandas as pd
import ace_tools_open as tools

rates, errors = get_rates_database()

tools.display_dataframe_to_user("Rates :", rates)
try:
    tools.display_dataframe_to_user("Errors :", errors)
except:
    tools.display_dataframe_to_user("Errors :", pd.DataFrame())
# Out:
#  88%|████████▊ | 211/239 [05:57<01:34,  3.38s/it]
# ❌ Erreur : Message: out of memory
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:199:5
# UnknownError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:910:5
# wrap@chrome://remote/content/shared/webdriver/Errors.sys.mjs:145:12
# sendError@chrome://remote/content/marionette/message.sys.mjs:284:29
#  89%|████████▊ | 212/239 [06:27<05:08, 11.41s/it]
# ❌ Erreur : Message: Navigation timed out after 30000 ms
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:199:5
# TimeoutError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:812:5
# bail@chrome://remote/content/marionette/sync.sys.mjs:197:19
# 100%|██████████| 239/239 [07:19<00:00,  1.84s/it]
# Rates :
# ...
