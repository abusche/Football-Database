# %% [markdown]
# # Création de la base de données
#
# Ce code a pour but de créer des fonctions pour webscraper des données sur les résultats des matchs de foot des plus grands championnats.

# %% [markdown]
# ## 1) Matchs

# %%
from match_functions import get_match_database

# %%
get_match_database('2024-08-15', '2024-08-25', leagues = ["Ligue 1"], save = True, add = False)
# Out:
# Extraction des liens...
#
# Chargement : 100 %
# Extraction terminée en  3.98 minutes
#
# Chargement de la base de données...
#
# Extraction terminée en  6.42 minutes
#    Championnat    Journée     Saison              Equipe1  \
# 0      Ligue 1  Journée 1  2024/2025             Le Havre
# 1      Ligue 1  Journée 1  2024/2025                Brest
# 2      Ligue 1  Journée 1  2024/2025                Reims
# 3      Ligue 1  Journée 1  2024/2025               Monaco
# 4      Ligue 1  Journée 1  2024/2025              Auxerre
# 5      Ligue 1  Journée 1  2024/2025          Montpellier
# 6      Ligue 1  Journée 1  2024/2025             Toulouse
# 7      Ligue 1  Journée 1  2024/2025               Angers
# 8      Ligue 1  Journée 1  2024/2025               Rennes
# 9      Ligue 1  Journée 2  2024/2025  Paris Saint-Germain
# 10     Ligue 1  Journée 2  2024/2025                 Lyon
# 11     Ligue 1  Journée 2  2024/2025                Lille
# 12     Ligue 1  Journée 2  2024/2025        Saint-Étienne
# 13     Ligue 1  Journée 2  2024/2025                 Lens
# 14     Ligue 1  Journée 2  2024/2025                 Nice
# 15     Ligue 1  Journée 2  2024/2025               Nantes
# 16     Ligue 1  Journée 2  2024/2025           Strasbourg
# 17     Ligue 1  Journée 2  2024/2025            Marseille
#
#                 Equipe2  Score1  Score2  xG1  xG2  Possession1  ...  Heure  \
# 0   Paris Saint-Germain       1       4  0.2  2.9         0.24  ...  20:45
# 1             Marseille       1       5  1.3  2.4         0.50  ...  17:00
# 2                 Lille       0       2  0.1  2.1         0.32  ...  19:00
# 3         Saint-Étienne       1       0  2.0  0.4         0.61  ...  21:00
# 4                  Nice       2       1  1.8  0.7         0.45  ...  15:00
# 5            Strasbourg       1       1  1.3  0.9         0.42  ...  17:00
# 6                Nantes       0       0  1.7  0.5         0.54  ...  17:00
# 7                  Lens       0       1  0.4  1.2         0.42  ...  17:00
# 8                  Lyon       3       0  2.0  2.1         0.47  ...  20:45
# 9           Montpellier       6       0  3.8  0.6         0.68  ...  20:45
# 10               Monaco       0       2  0.0  2.2         0.40  ...  17:00
# 11               Angers       2       0  0.9  0.6         0.64  ...  19:00
# 12             Le Havre       0       2  1.1  2.4         0.59  ...  21:00
# 13                Brest       2       0  2.9  0.9         0.52  ...  15:00
# 14             Toulouse       1       1  1.3  1.0         0.57  ...  17:00
# 15              Auxerre       2       0  1.4  1.1         0.36  ...  17:00
# 16               Rennes       3       1  0.7  1.1         0.59  ...  17:00
# 17                Reims       2       2  3.0  0.9         0.66  ...  20:45
#
#                     Arbitre  Affluence  \
# 0             Willy Delajod      23167
# 1            Benoît Bastien      14962
# 2           Eric Wattellier      14755
# 3            Clément Turpin      14250
# 4          Romain Lissorgue      16354
# 5           Mathieu Vernice      15706
# 6             Jeremy Stinat      25491
# 7            Thomas Léonard      14811
# 8             Benoît Millot      26026
# 9           Marc Bollengier      46000
# 10       Stéphanie Frappart      54392
# 11      Abdelatif Kherradji      36906
# 12            Florent Batta      16958
# 13          Jérémie Pignard      37435
# 14          Bastien Dechepy      21656
# 15             Gaël Angoula      31077
# 16          Eric Wattellier      19026
# 17  Hakim Ben El Hadj Salem      63841
#
#                                       Stade           Entraineur1  \
# 0                              Stade Océane         Didier Digard
# 1                      Stade Francis-Le Blé              Eric Roy
# 2                     Stade Auguste-Delaune           Luka Elsner
# 3                            Stade Louis II            Adi Hütter
# 4                 Stade de l'Abbé Deschamps  Christophe Pélissier
# 5             Stade de la Mosson-Mondial 98   Michel Der Zakarian
# 6                       Stadium de Toulouse       Carles Martínez
# 7                        Stade Raymond Kopa      Alexandre Dujeux
# 8                              Roazhon Park        Julien Stéphan
# 9                          Parc des Princes          Luis Enrique
# 10                         Groupama Stadium           Pierre Sage
# 11    Decathlon Arena - Stade Pierre-Mauroy         Bruno Génésio
# 12                  Stade Geoffroy-Guichard    Olivier Dall’Oglio
# 13                   Stade Bollaert-Delelis            Will Still
# 14                          Allianz Riviera          Franck Haise
# 15  Stade de la Beaujoire - Louis Fonteneau     Antoine Kombouaré
# 16                       Stade de la Meinau         Liam Rosenior
# 17                         Orange Vélodrome      Roberto De Zerbi
#
#              Entraineur2  Dispositif1  Dispositif2  \
# 0           Luis Enrique        4-3-3        4-3-3
# 1       Roberto De Zerbi        4-3-3      4-2-3-1
# 2          Bruno Génésio        4-3-3        5-4-1
# 3     Olivier Dall’Oglio        4-4-2      4-1-4-1
# 4           Franck Haise        4-4-2        3-4-3
# 5          Liam Rosenior      4-2-3-1        3-4-3
# 6      Antoine Kombouaré        3-4-3      4-2-3-1
# 7             Will Still        5-3-2      3-4-1-2
# 8            Pierre Sage    4-1-2-1-2        4-3-3
# 9    Michel Der Zakarian        4-3-3        5-3-2
# 10            Adi Hütter      4-2-3-1      4-2-3-1
# 11      Alexandre Dujeux        3-4-3        5-3-2
# 12         Didier Digard      4-1-4-1        5-4-1
# 13              Eric Roy      3-4-1-2        4-3-3
# 14       Carles Martínez        3-5-2        3-4-3
# 15  Christophe Pélissier      4-2-3-1      4-2-3-1
# 16        Julien Stéphan      3-4-1-2      4-3-1-2
# 17           Luka Elsner      4-2-3-1        4-3-3
#
#                                          Composition1  \
# 0   [Arthur Desmas, Gautier Lloris, Etienne Youte ...
# 1   [Marco Bizot, Brendan Chardonnet, Romain Del C...
# 2   [Yehvann Diouf, Joseph Okumu, Valentin Atangan...
# 3   [Philipp Köhn, Vanderson, Thilo Kehrer, Denis ...
# 4   [Donovan Léon, Gabriel Osho, Jubal, Theo Bair,...
# 5   [Benjamin Lecomte, Modibo Sagnan, Arnaud Nordi...
# 6   [Guillaume Restes, Rasmus Nicolaisen, Charlie ...
# 7   [Yahia Fofana, Carlens Arcus, Jacques Ekomie, ...
# 8   [Steve Mandanda, Christopher Wooh, Azor Matusi...
# 9   [Gianluigi Donnarumma, Achraf Hakimi, Marquinh...
# 10  [Lucas Perri, Maxence Caqueret, Alexandre Laca...
# 11  [Lucas Chevalier, Aïssa Mandi, Alexsandro Ribe...
# 12  [Gautier Larsonneur, Yunis Abdelhamid, Ibrahim...
# 13  [Brice Samba, Ruben Aguilar, Kevin Danso, Flor...
# 14  [Marcin Bułka, Dante, Hicham Boudaoui, Pablo R...
# 15  [Alban Lafont, Jean-Kevin Duverne, Pedro Chiri...
# 16  [Karl-Johan Johnsson, Diego Moreira, Andrey Sa...
# 17  [Gerónimo Rulli, Quentin Merlin, Leonardo Bale...
#
#                                          Composition2
# 0   [Gianluigi Donnarumma, Achraf Hakimi, Gonçalo ...
# 1   [Gerónimo Rulli, Quentin Merlin, Leonardo Bale...
# 2   [Lucas Chevalier, Aïssa Mandi, Alexsandro Ribe...
# 3   [Gautier Larsonneur, Yunis Abdelhamid, Ibrahim...
# 4   [Marcin Bułka, Dante, Pablo Rosario, Bilal Bra...
# 5   [Karl-Johan Johnsson, Emanuel Emegha, Caleb Wi...
# 6   [Alban Lafont, Pedro Chirivella, Douglas, Tino...
# 7   [Brice Samba, Ruben Aguilar, Kevin Danso, Flor...
# 8   [Lucas Perri, Maxence Caqueret, Abner, Saïd Be...
# 9   [Benjamin Lecomte, Boubakar Kouyaté, Modibo Sa...
# 10  [Philipp Köhn, Vanderson, Thilo Kehrer, Denis ...
# 11  [Yahia Fofana, Carlens Arcus, Jacques Ekomie, ...
# 12  [Arthur Desmas, Gautier Lloris, Oussama Targha...
# 13  [Marco Bizot, Brendan Chardonnet, Kenny Lala, ...
# 14  [Guillaume Restes, Rasmus Nicolaisen, Mark McK...
# 15  [Donovan Léon, Gabriel Osho, Jubal, Theo Bair,...
# 16  [Steve Mandanda, Adrien Truffert, Christopher ...
# 17  [Yehvann Diouf, Joseph Okumu, Valentin Atangan...
#
# [18 rows x 68 columns]

# %% [markdown]
# ## 2) Joueurs

# %%
from player_functions import get_player_database

# %%
get_player_database('2024-08-15', '2024-08-25', leagues = ["Ligue 1"], save = False, add = False)
# Out:
# Extraction des liens...
#
# Chargement : 100 %
# Extraction terminée en  1.29 minutes
#
# Chargement de la base de données...
#
# Extraction terminée en  4.95 minutes
#                                           Match_Index                Nom  \
# 0   Le Havre_Paris Saint-Germain_Ligue 1_Journée 1...      Josué Casimir
# 1   Le Havre_Paris Saint-Germain_Ligue 1_Journée 1...     Antoine Joujou
# 2   Le Havre_Paris Saint-Germain_Ligue 1_Journée 1...       Steve Ngoura
# 3   Le Havre_Paris Saint-Germain_Ligue 1_Journée 1...     Yassine Kechta
# 4   Le Havre_Paris Saint-Germain_Ligue 1_Journée 1...     Kandet Diawara
# ..                                                ...                ...
# 23        Marseille_Reims_Ligue 1_Journée 2_2024/2025      Sergio Akieme
# 24        Marseille_Reims_Ligue 1_Journée 2_2024/2025   Emmanuel Agbadou
# 25        Marseille_Reims_Ligue 1_Journée 2_2024/2025       Joseph Okumu
# 26        Marseille_Reims_Ligue 1_Journée 2_2024/2025        Nhoa Sangui
# 27        Marseille_Reims_Ligue 1_Journée 2_2024/2025      Yehvann Diouf
#
#    Numéro Nationalité  Poste     Âge Minutes Buts PD PénM  ... %PassLanc  \
# 0      23         FRA  FW,LW  22-327      90    0  0    0  ...       NaN
# 1      21         FRA     LW  21-157      75    0  0    0  ...       NaN
# 2      77         FRA     FW  19-176      15    0  0    0  ...       NaN
# 3       8         MAR     RW  22-173      86    0  0    0  ...       NaN
# 4      15         GUI     RW  24-188       4    0  0    0  ...       NaN
# ..    ...         ...    ...     ...     ...  ... ..  ...  ...       ...
# 23     18         ESP     LB  26-253      90    1  0    0  ...       NaN
# 24     24         CIV     CB  27-069      90    0  0    0  ...       NaN
# 25      2         KEN     CB  27-091      90    0  0    0  ...       NaN
# 26     55         FRA     RB  18-180      90    0  0    0  ...       NaN
# 27     94         FRA     GK  24-283      90    0  0    0  ...      44.0
#
#    LongPassMoy DégSixMetres %DégSixMetres LongMoySixMetres CtrConc CtrStop  \
# 0          NaN          NaN           NaN              NaN     NaN     NaN
# 1          NaN          NaN           NaN              NaN     NaN     NaN
# 2          NaN          NaN           NaN              NaN     NaN     NaN
# 3          NaN          NaN           NaN              NaN     NaN     NaN
# 4          NaN          NaN           NaN              NaN     NaN     NaN
# ..         ...          ...           ...              ...     ...     ...
# 23         NaN          NaN           NaN              NaN     NaN     NaN
# 24         NaN          NaN           NaN              NaN     NaN     NaN
# 25         NaN          NaN           NaN              NaN     NaN     NaN
# 26         NaN          NaN           NaN              NaN     NaN     NaN
# 27        40.5            4          50.0             39.8      14       0
#
#    %CtrStop ActDéfSurfRép DistMoyActDéf
# 0       NaN           NaN           NaN
# 1       NaN           NaN           NaN
# 2       NaN           NaN           NaN
# 3       NaN           NaN           NaN
# 4       NaN           NaN           NaN
# ..      ...           ...           ...
# 23      NaN           NaN           NaN
# 24      NaN           NaN           NaN
# 25      NaN           NaN           NaN
# 26      NaN           NaN           NaN
# 27      0.0             0           3.0
#
# [552 rows x 120 columns]

# %% [markdown]
# ## 3) Tirs

# %%
from shoot_functions import get_shoot_database

# %%
get_shoot_database('2024-08-15', '2024-08-25', leagues = ["Ligue 1"], save = False, add = False)
# Out:
# Extraction des liens...
#
# Chargement : 100 %
# Extraction terminée en  1.28 minutes
#
# Chargement de la base de données...
#
# Extraction terminée en  3.57 minutes
#                                           Match_Index Minutes  \
# 0   Le Havre_Paris Saint-Germain_Ligue 1_Journée 1...       3
# 1   Le Havre_Paris Saint-Germain_Ligue 1_Journée 1...      24
# 2   Le Havre_Paris Saint-Germain_Ligue 1_Journée 1...      39
# 3   Le Havre_Paris Saint-Germain_Ligue 1_Journée 1...      39
# 4   Le Havre_Paris Saint-Germain_Ligue 1_Journée 1...      41
# ..                                                ...     ...
# 29        Marseille_Reims_Ligue 1_Journée 2_2024/2025      87
# 30        Marseille_Reims_Ligue 1_Journée 2_2024/2025    90+3
# 31        Marseille_Reims_Ligue 1_Journée 2_2024/2025    90+4
# 32        Marseille_Reims_Ligue 1_Journée 2_2024/2025    90+4
# 33        Marseille_Reims_Ligue 1_Journée 2_2024/2025    90+8
#
#                 Joueur      Equipe    xG  PSxG Résultats Distance  \
# 0          Lee Kang-in   Paris S-G  0.07  0.52       But       14
# 1    Randal Kolo Muani   Paris S-G  0.20  0.00  Montants       10
# 2      Abdoulaye Touré    Le Havre  0.05  0.00   Bloquée       24
# 3      Abdoulaye Touré    Le Havre  0.04  0.09    Sauvée       25
# 4       Antoine Joujou    Le Havre  0.04  0.00   Bloquée       17
# ..                 ...         ...   ...   ...       ...      ...
# 29            Jon Rowe   Marseille  0.07  0.00   Bloquée       11
# 30      Quentin Merlin   Marseille  0.01  0.00   Bloquée       24
# 31  Geoffrey Kondogbia   Marseille  0.07  0.00   Bloquée       17
# 32     Lilian Brassier   Marseille  0.03  0.12    Sauvée       16
# 33     Mason Greenwood   Marseille  0.03  0.00   Bloquée       18
#
#           Corps             Notes          AMT1Joueur  \
# 0   Pied gauche            Déviée       Gonçalo Ramos
# 1          Tête                         Achraf Hakimi
# 2   Pied gauche                         Josué Casimir
# 3    Pied droit                       Abdoulaye Touré
# 4    Pied droit                        Yassine Kechta
# ..          ...               ...                 ...
# 29  Pied gauche  Reprise de volée      Quentin Merlin
# 30  Pied gauche                      Valentin Carboni
# 31  Pied gauche                         Luis Henrique
# 32  Pied gauche                    Geoffrey Kondogbia
# 33  Pied gauche                      Valentin Carboni
#
#                 AMT1Evenement       AMT2Joueur              AMT2Evenement
# 0   Passe (sur action de jeu)    Achraf Hakimi  Passe (sur action de jeu)
# 1   Passe (sur action de jeu)      Lee Kang-in  Passe (sur action de jeu)
# 2   Passe (sur action de jeu)   Rassoul Ndiaye  Passe (sur action de jeu)
# 3                         Tir
# 4   Passe (sur action de jeu)    Josué Casimir  Passe (sur action de jeu)
# ..                        ...              ...                        ...
# 29  Passe (sur action de jeu)  Mason Greenwood  Passe (sur action de jeu)
# 30  Passe (sur action de jeu)    Luis Henrique  Passe (sur action de jeu)
# 31  Passe (sur action de jeu)   Quentin Merlin  Passe (sur action de jeu)
# 32                        Tir
# 33  Passe (sur action de jeu)   Quentin Merlin  Passe (sur action de jeu)
#
# [455 rows x 14 columns]

# %% [markdown]
# ## 4) Fonction final

# %%
from shoot_functions import get_shoot
from player_functions import get_stats_player
from match_functions import get_match
from base_functions import get_link_matchs, page
from datetime import datetime, timedelta
import random
import re
import functools
import time
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import dateparser
import locale

# %%
def get_database(date_start, date_end, leagues, folder):
    
    t = time.time()
    secs = []
    
    links = get_link_matchs(date_start, date_end, leagues)
    
    var = ["Championnat", "Journée", "Saison", "Equipe1", "Equipe2", "Score1", "Score2", "xG1", "xG2", "Possession1", "Possession2", "Passes1", "Passes réussies1", "% Passes réussies1", "Passes2", "Passes réussies2", "% Passes réussies2", "Tirs1", "Tirs cadrés1", "% Tirs cadrés1", "Tirs2", "Tirs cadrés2", "% Tirs cadrés2", "Arrêts possibles1", "Arrêts1", "% Arrêts1", "Arrêts possibles2", "Arrêts2", "% Arrêts2", "Fautes1" , "Fautes2", "Corners1", "Corners2", "Centres1", "Centres2", "Touches1", "Touches2", "Tacles1", "Tacles2", "Interceptions1", "Interceptions2", "Duels aériens gagnés1", "Duels aériens gagnés2", "Dégagements1", "Dégagements2", "Hors-jeux1","Hors-jeux2", "Dégagements au six mètres1", "Dégagements au six mètres2", "Rentrée de touche1", "Rentrée de touche2", "Longs ballons1", "Longs ballons2", "Cartons jaunes1", "Cartons jaunes2", "Cartons rouges1", "Cartons rouges2", "Date", "Heure", "Arbitre", "Affluence", "Stade", "Entraineur1", "Entraineur2", "Dispositif1", "Dispositif2", "Composition1", "Composition2"]
    matchs = []
    players = pd.DataFrame()
    shoots = pd.DataFrame()
    
    z=0 # Initialisation d'un compteur
    print("Chargement de la base de données...")
    print(" ")
    
    for link in links:
        z+=1
        soup = page(link)
        
        print("Chargement : ", round((z/len(links))*100), "%", end="\r")
        print(link, end = "\r")
        test = time.time()
        
        shoot = get_shoot(soup)
        shoots = pd.concat([shoots, shoot])
        
        player = get_stats_player(soup)
        players = pd.concat([players, player])
        
        match = get_match(soup)
        matchs.append(match)
        
        secs.append(time.time() - test)
        
    matchs = pd.DataFrame(matchs, columns=var)
    
    matchs.to_csv(f"{folder}/matchs.csv", index=False)
    players.to_csv(f"{folder}/players.csv", index=False)
    shoots.to_csv(f"{folder}/shoots.csv", index=False)
    
    print("Extraction terminée en ", round((time.time() - t)/60, 2), "minutes")
    
    return secs

# %%
secs = get_database('2023-08-01', '2024-07-31', leagues = ["Ligue 1"], folder = "database")
# Out:
# Extraction des liens...
#
# Chargement : 100 %
# Extraction terminée en  41.96 minutes
#
# Chargement de la base de données...
#
# Extraction terminée en  100.9 minutesLille-Nice-19-Mai-2024-Ligue-1e-1-Ligue-1e-1ue-1-1ue-1e-111

# %%
import numpy as np
np.mean(secs)
# Out:
# 3.066168641732409
